# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("student-por.csv")

# %% [markdown]
# # DESCRIPTIVE

# %%
df.head()
# Out:
#   school sex  age address famsize Pstatus  ...  Walc  health absences  G1  G2  G3
# 0     GP   F   18       U     GT3       A  ...     1       3        4   0  11  11
# 1     GP   F   17       U     GT3       T  ...     1       3        2   9  11  11
# 2     GP   F   15       U     LE3       T  ...     3       3        6  12  13  12
# 3     GP   F   15       U     GT3       T  ...     1       5        0  14  14  14
# 4     GP   F   16       U     GT3       T  ...     2       5        0  11  13  13
#
# [5 rows x 33 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 649 entries, 0 to 648
# Data columns (total 33 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      649 non-null    object
#  1   sex         649 non-null    object
#  2   age         649 non-null    int64
#  3   address     649 non-null    object
#  4   famsize     649 non-null    object
#  5   Pstatus     649 non-null    object
#  6   Medu        649 non-null    int64
#  7   Fedu        649 non-null    int64
#  8   Mjob        649 non-null    object
#  9   Fjob        649 non-null    object
#  10  reason      649 non-null    object
#  11  guardian    649 non-null    object
#  12  traveltime  649 non-null    int64
#  13  studytime   649 non-null    int64
#  14  failures    649 non-null    int64
#  15  schoolsup   649 non-null    object
#  16  famsup      649 non-null    object
#  17  paid        649 non-null    object
#  18  activities  649 non-null    object
# ...

# %%
df['Total_grades']=(df['G1']+df['G2']+df['G3'])/3
df.Total_grades = df.Total_grades.astype(int)

df=df.drop(columns=['G1','G2','G3'])
df.head()
# Out:
#   school sex  age address famsize  ... Dalc  Walc  health absences Total_grades
# 0     GP   F   18       U     GT3  ...    1     1       3        4            7
# 1     GP   F   17       U     GT3  ...    1     1       3        2           10
# 2     GP   F   15       U     LE3  ...    2     3       3        6           12
# 3     GP   F   15       U     GT3  ...    1     1       5        0           14
# 4     GP   F   16       U     GT3  ...    1     2       5        0           12
#
# [5 rows x 31 columns]

# %%
df.describe()
# Out:
#               age        Medu        Fedu  ...      health    absences  Total_grades
# count  649.000000  649.000000  649.000000  ...  649.000000  649.000000    649.000000
# mean    16.744222    2.514638    2.306626  ...    3.536210    3.659476     11.298921
# std      1.218138    1.134552    1.099931  ...    1.446259    4.640759      2.858820
# min     15.000000    0.000000    0.000000  ...    1.000000    0.000000      1.000000
# 25%     16.000000    2.000000    1.000000  ...    2.000000    0.000000     10.000000
# 50%     17.000000    2.000000    2.000000  ...    4.000000    2.000000     11.000000
# 75%     18.000000    4.000000    3.000000  ...    5.000000    6.000000     13.000000
# max     22.000000    4.000000    4.000000  ...    5.000000   32.000000     18.000000
#
# [8 rows x 14 columns]

# %%
df.isnull().sum()
# Out:
# school          0
# sex             0
# age             0
# address         0
# famsize         0
# Pstatus         0
# Medu            0
# Fedu            0
# Mjob            0
# Fjob            0
# reason          0
# guardian        0
# traveltime      0
# studytime       0
# failures        0
# schoolsup       0
# famsup          0
# paid            0
# activities      0
# nursery         0
# higher          0
# internet        0
# romantic        0
# famrel          0
# freetime        0
# goout           0
# Dalc            0
# Walc            0
# health          0
# absences        0
# Total_grades    0
# dtype: int64

# %%
plt.figure(figsize=(9, 6))
plt.yticks(np.arange(0, 200, 20))
age_dist = df['age']
plt.hist(x=age_dist, alpha=0.7, edgecolor='black')
plt.xlabel('Age', fontsize=12)
plt.ylabel('Number of Students', fontsize=12)
plt.title('Age Distribution of Students', fontsize=14)
plt.show()

# %%
plt.figure(figsize=(8, 6))
gender_labels = ['F - Female', 'M - Male']
gender_dist = df['sex']
gender_plot = sns.countplot(x=df['sex'], hue=df['sex'], dodge=False)
plt.yticks(np.arange(0, 425, 50))
plt.xlabel('Gender', fontsize=12)
plt.ylabel('Number of Students', fontsize=12)
plt.title('Gender Distribution', fontsize=14)
plt.legend(labels=gender_labels, loc='upper right')
plt.show()

# %%
plt.figure(figsize=(8, 6))
activities_labels = ['No', 'Yes']
sns.countplot(x=df['activities'], hue=df['sex'], dodge=True)
plt.yticks(np.arange(0, 150, 25))
plt.xlabel('Have Activities?', fontsize=12)
plt.ylabel('Number of Students', fontsize=12)
plt.title('Extracurricular Activities per Gender', fontsize=14)
plt.legend(labels=gender_labels, loc='upper right')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.countplot(x=df['traveltime'])
plt.yticks(np.arange(0, 400, 25))
plt.xlabel('Travel Time Category', fontsize=12)
plt.ylabel('Number of Students', fontsize=12)
plt.title('Travel Time from Home to School', fontsize=14)
plt.show()

# %%
plt.figure(figsize=(8, 6))
study_labels = ['1 - <2 hours', '2 - 2-5 hours', '3 - 5-10 hours', '4 - >10 hours']
sns.countplot(x=df['studytime'], dodge=True)
plt.yticks(np.arange(0, 350, 50))
plt.xlabel('Weekly Study Hours Category', fontsize=12)
plt.ylabel('Number of Students', fontsize=12)
plt.title('Weekly Study Hours', fontsize=14)
plt.show()
# ************************************************

# %%
gender_labels_2 = ['Female', 'Male']
plt.figure(figsize=(11, 6))
sns.barplot(x=df['age'], y=df['absences'], hue=df['sex'], ci=None)
plt.yticks(np.arange(0, 24, 2))
plt.xlabel('Age', fontsize=12)
plt.ylabel('Number of Absences', fontsize=12)
plt.title('Number of Absenses per Age', fontsize=14)
plt.legend(labels=gender_labels_2, loc='upper right')
plt.show()
# 21 22 ******************* Why *************************

# %%
# remove 0 failure
plt.figure(figsize=(9, 6))
failure_labels = ['0 failures', '1 failure', '2 failures', '3 failures']
sns.countplot(x=df['age'], hue=df['failures'])
plt.yticks(np.arange(0, 170, 10))
plt.xlabel('Age', fontsize=12)
plt.ylabel('Number of Failures', fontsize=12)
plt.title('Number of Failures per Age', fontsize=14)
plt.legend(labels=failure_labels, loc='upper right')
plt.show()

# %%
fig1 = plt.figure(figsize=(25, 15))
ax1 = fig1.add_subplot(2, 2, 1)
ax1 = sns.countplot(x=df['Total_grades'], hue=df['sex'])
plt.yticks(np.arange(0, 70, 10))
plt.xlabel('Grade', fontsize=12)
plt.ylabel('Number of Students', fontsize=12)
plt.title(' Grades', fontsize=14)
plt.legend(labels=gender_labels_2, loc='upper right')

# %%
plt.figure(figsize=(12,12))
sns.heatmap(df.corr(), cmap='YlGn', annot=True, fmt = ".2f")
plt.xticks(rotation=45)
plt.yticks(rotation=0)
plt.title('Correlation Map')
plt.show()

# %% [markdown]
# # **ADD More feature**

# %%
def conv_binary(df, col_name_list):
    for col in col_name_list:
        df[col].replace(to_replace=["yes", "no"], value=[1,0], inplace=True)

# %%
# Yes No Columns to binary
col_lst = ['schoolsup', 'famsup', 'paid', 'activities', 'nursery', 'higher', 'internet', 'romantic']
conv_binary(df, col_lst)

# %%
df
# Out:
#     school sex  age address famsize  ... Dalc  Walc  health absences Total_grades
# 0       GP   F   18       U     GT3  ...    1     1       3        4            7
# 1       GP   F   17       U     GT3  ...    1     1       3        2           10
# 2       GP   F   15       U     LE3  ...    2     3       3        6           12
# 3       GP   F   15       U     GT3  ...    1     1       5        0           14
# 4       GP   F   16       U     GT3  ...    1     2       5        0           12
# ..     ...  ..  ...     ...     ...  ...  ...   ...     ...      ...          ...
# 644     MS   F   19       R     GT3  ...    1     2       5        4           10
# 645     MS   F   18       U     LE3  ...    1     1       1        4           15
# 646     MS   F   18       U     GT3  ...    1     1       5        6           10
# 647     MS   M   17       U     LE3  ...    3     4       2        6           10
# ...

# %%
df['sex'].value_counts()/df.shape[0]
# Out:
# F    0.590139
# M    0.409861
# Name: sex, dtype: float64

# %%
df['address'].value_counts()/df.shape[0]
# most of the student in urban area
# Out:
# U    0.696456
# R    0.303544
# Name: address, dtype: float64

# %%
df['Pstatus'].value_counts()/df.shape[0]
#  87% live with their parent
# Out:
# T    0.876733
# A    0.123267
# Name: Pstatus, dtype: float64

# %%
df['famsize'].value_counts()/df.shape[0]
# family size (binary: 'LE3' - less or equal to 3 or 'GT3' - greater than 3)
# 70% of the students have more than 3
# Out:
# GT3    0.70416
# LE3    0.29584
# Name: famsize, dtype: float64

# %%
df['Medu'].value_counts()/df.shape[0]
# Educated Mothers   : (numeric: 0 - none, 1 - primary education (4th grade), 2 - 5th to 9th grade, 3 - secondary
# Out:
# 2    0.286595
# 4    0.269646
# 1    0.220339
# 3    0.214176
# 0    0.009245
# Name: Medu, dtype: float64

# %%
df['Fedu'].value_counts()/df.shape[0]
# Educated Father
# Out:
# 2    0.322034
# 1    0.268105
# 3    0.201849
# 4    0.197227
# 0    0.010786
# Name: Fedu, dtype: float64

# %%
df['studytime'].value_counts()/df.shape[0]
# weekly study time (numeric: 1 - <2 hours, 2 - 2 to 5 hours, 3 - 5 to 10 hours, or 4 - >10 hours)
# Out:
# 2    0.469954
# 1    0.326656
# 3    0.149461
# 4    0.053929
# Name: studytime, dtype: float64

# %% [markdown]
# **Convert the rest of the data (Not Yes/No**) to binary

# %% [markdown]
# * student's school (binary: 'GP' - Gabriel Pereira or 'MS' - Mousinho da Silveira)
# * parent's cohabitation status (binary: 'T' - living together or 'A' - apart)

# %%
df["school"].replace(to_replace=["GP", "MS"], value=[1,0], inplace=True)
df["sex"].replace(to_replace=["M", "F"], value=[1,0], inplace=True)
df["address"].replace(to_replace=["U", "R"], value=[1,0], inplace=True)
df["famsize"].replace(to_replace=["LE3", "GT3"], value=[1,0], inplace=True)
df["Pstatus"].replace(to_replace=["T", "A"], value=[1,0], inplace=True)

# %%
df[['schoolsup', 'famsup', 'paid', 'activities', 'nursery', 'higher', 'internet', 'romantic','school','sex','address','famsize','Pstatus']]
# Out:
#      schoolsup  famsup  paid  activities  ...  sex  address  famsize  Pstatus
# 0            1       0     0           0  ...    0        1        0        0
# 1            0       1     0           0  ...    0        1        0        1
# 2            1       0     0           0  ...    0        1        1        1
# 3            0       1     0           1  ...    0        1        0        1
# 4            0       1     0           0  ...    0        1        0        1
# ..         ...     ...   ...         ...  ...  ...      ...      ...      ...
# 644          0       0     0           1  ...    0        0        0        1
# 645          0       1     0           0  ...    0        1        1        1
# 646          0       0     0           1  ...    0        1        0        1
# 647          0       0     0           0  ...    1        1        1        1
# 648          0       0     0           0  ...    1        0        1        1
#
# [649 rows x 13 columns]

# %%
df
# Out:
#      school  sex  age  address  ...  Walc  health  absences  Total_grades
# 0         1    0   18        1  ...     1       3         4             7
# 1         1    0   17        1  ...     1       3         2            10
# 2         1    0   15        1  ...     3       3         6            12
# 3         1    0   15        1  ...     1       5         0            14
# 4         1    0   16        1  ...     2       5         0            12
# ..      ...  ...  ...      ...  ...   ...     ...       ...           ...
# 644       0    0   19        0  ...     2       5         4            10
# 645       0    0   18        1  ...     1       1         4            15
# 646       0    0   18        1  ...     1       5         6            10
# 647       0    1   17        1  ...     4       2         6            10
# 648       0    1   18        0  ...     4       5         4            10
#
# [649 rows x 31 columns]

# %% [markdown]
# # **Data Visualization**

# %%
fig, ax = plt.subplots(figsize=(20,15))
sns.heatmap(df.corr(), cmap='mako', annot=True, fmt="0.2f")

# %% [markdown]
# # **Which one have an effect on student Grade**

# %%
df['Total_grades'] = df['Total_grades'].apply(np.int64)

# %%
df
# Out:
#      school  sex  age  address  ...  Walc  health  absences  Total_grades
# 0         1    0   18        1  ...     1       3         4             7
# 1         1    0   17        1  ...     1       3         2            10
# 2         1    0   15        1  ...     3       3         6            12
# 3         1    0   15        1  ...     1       5         0            14
# 4         1    0   16        1  ...     2       5         0            12
# ..      ...  ...  ...      ...  ...   ...     ...       ...           ...
# 644       0    0   19        0  ...     2       5         4            10
# 645       0    0   18        1  ...     1       1         4            15
# 646       0    0   18        1  ...     1       5         6            10
# 647       0    1   17        1  ...     4       2         6            10
# 648       0    1   18        0  ...     4       5         4            10
#
# [649 rows x 31 columns]

# %%
plt.title('Average Grades Based on Parents Cohabitation')
plt.xlabel('Separated or Living Together')
plt.ylabel('Avg Grade')
sns.barplot(x='Pstatus', y='Total_grades', data=df)
#  Which one have an effect

# %%
df.groupby('schoolsup')['Total_grades'].mean().plot(kind='bar')

# %%
sns.barplot(x='famsize', y='Total_grades', data=df)
plt.title('Family Size Affect on Grades')
plt.xlabel('Family Size')
plt.ylabel('Final Grades')
# Out:
# Text(0, 0.5, 'Final Grades')

# %%
fix, ax = plt.subplots(1,2, figsize=(20,10))
plt.xlabel('Parents Highest Level of Education')
plt.ylabel('Final Grades')
sns.boxplot(x='Fedu', y='Total_grades', data=df, orient='v', ax=ax[0])
sns.boxplot(x='Medu', y='Total_grades', data=df, orient='v', ax=ax[1])

# %%
df['Fedu'].describe()
# Out:
# count    649.000000
# mean       2.306626
# std        1.099931
# min        0.000000
# 25%        1.000000
# 50%        2.000000
# 75%        3.000000
# max        4.000000
# Name: Fedu, dtype: float64

# %%
sns.barplot(x='romantic', y='Total_grades', data=df)
plt.xlabel('Relationship Status')
plt.ylabel('Final Grades')
# Out:
# Text(0, 0.5, 'Final Grades')

# %%
# workday alcohol consumption (numeric: from 1 - very low to 5 - very high)
sns.violinplot(x='Dalc', y='Total_grades', inner='quartile', data=df)
plt.xlabel('Alcohol Consumption During the Week')
plt.ylabel('Final Grades')
# Out:
# Text(0, 0.5, 'Final Grades')

# %%
df['Dalc'].value_counts()
# Out:
# 1    451
# 2    121
# 3     43
# 5     17
# 4     17
# Name: Dalc, dtype: int64

# %%
df
# Out:
#      school  sex  age  address  ...  Walc  health  absences  Total_grades
# 0         1    0   18        1  ...     1       3         4             7
# 1         1    0   17        1  ...     1       3         2            10
# 2         1    0   15        1  ...     3       3         6            12
# 3         1    0   15        1  ...     1       5         0            14
# 4         1    0   16        1  ...     2       5         0            12
# ..      ...  ...  ...      ...  ...   ...     ...       ...           ...
# 644       0    0   19        0  ...     2       5         4            10
# 645       0    0   18        1  ...     1       1         4            15
# 646       0    0   18        1  ...     1       5         6            10
# 647       0    1   17        1  ...     4       2         6            10
# 648       0    1   18        0  ...     4       5         4            10
#
# [649 rows x 31 columns]

# %%
df.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'Total_grades'],
#       dtype='object')

# %%
fig, ax = plt.subplots(figsize=(20,15))
sns.heatmap(df.corr(), cmap='mako', annot=True, fmt="0.2f")

# %% [markdown]
# -age has low positive correlation with failure
#
# -Medu & Fedu has moderate positive    correlation & they both have low positive correlation with grades
#
# -studytime & grades have a low positive correlation
#
# -failure has low negative correlation with grades
#
# -freetime has low positive correlation with goout
#
# -goout has low positive correlation with Walc
#
# -Walc has moderate positive correlation with Dalc and they both have negligible negative correlation

# %% [markdown]
# We can see some factors that affect grades:
#
#
# *   Alcohol usage
# *   Parents education have a great effect specialy with mother's

# %%
#PCA Analysis consider total garde ((g1+g2+g3) /3) target variable or/and Decision tree

# %% [markdown]
# # **Principal Component Analysis**

# %%
# STANDARDIZATION
from sklearn.preprocessing import StandardScaler
df0 = pd.read_csv("student-por.csv")
df1=df0[['G1', 'G2', 'G3' ]]
X_scaled = StandardScaler().fit_transform(df1)
print(X_scaled)
y = df['Total_grades']
print(df1.shape)
print(df1)
# Out:
# [[-4.15547029 -0.19581961 -0.28065755]
#  [-0.87456978 -0.19581961 -0.28065755]
#  [ 0.21906372  0.49113675  0.02911583]
#  ...
#  [-0.14548078  0.14765857 -0.90020431]
#  [-0.51002528 -0.53929779 -0.59043093]
#  [-0.51002528 -0.19581961 -0.28065755]]
# (649, 3)
#      G1  G2  G3
# 0     0  11  11
# 1     9  11  11
# 2    12  13  12
# 3    14  14  14
# 4    11  13  13
# ..   ..  ..  ..
# 644  10  11  10
# 645  15  15  16
# 646  11  12   9
# 647  10  10  10
# 648  10  11  11
#
# [649 rows x 3 columns]

# %%
# COVARIANCE MATRIX COMPUTATION
features = X_scaled.T
cov_matrix = np.cov(features)
cov_matrix
# Out:
# array([[1.00154321, 0.86631648, 0.82766241],
#        [0.86631648, 1.00154321, 0.91996552],
#        [0.82766241, 0.91996552, 1.00154321]])

# %%
# COMPUTE THE EIGENVALUES 
values, vectors = np.linalg.eig(cov_matrix)
values
# Out:
# array([2.74472405, 0.18339705, 0.07650853])

# %%
# COMPUTE THE EIGENVECTORS
vectors
# Out:
# array([[ 0.56638439,  0.80399984,  0.18108833],
#        [ 0.58685171, -0.23917992, -0.77356191],
#        [ 0.57863096, -0.54440539,  0.60729645]])

# %%
explained_variances = []
for i in range(len(values)):
    explained_variances.append(values[i] / np.sum(values))
 
print(np.sum(explained_variances), '\n', explained_variances)
# Out:
# 1.0
#  [0.9134982960440795, 0.06103815682116332, 0.025463547134757184]

# %%
projected_1 = X_scaled.dot(vectors.T[0])
projected_2 = X_scaled.dot(vectors.T[1])
res = pd.DataFrame(projected_1, columns=['PC1'])
res['PC2'] = projected_2
res['Y'] = y
res.head()
# Out:
#         PC1       PC2   Y
# 0 -2.630908 -3.141370   7
# 1 -0.772657 -0.503526  10
# 2  0.429146  0.042806  12
# 3  1.402150  0.209556  14
# 4  0.401918 -0.418930  12

# %%
plt.figure(figsize=(20, 10))
sns.scatterplot(res['PC1'], [0] * len(res), hue=res['Y'], s=200)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
plt.figure(figsize=(20, 10))
sns.scatterplot(res['PC1'], res['PC2'], hue=res['Y'], s=100)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# # Regr  + Classi (Model)
#
# > Linear SVC (classification)
#
#
# # Model for prediction (student pass or fail)
#
#
# > SGD regressor / random forest / decision Tree

# %% [markdown]
# ## **TEST**

# %%
df0['Total_grades']=(df0['G1']+df0['G2']+df0['G3'])/3
numeric = ['age', 'Medu', 'Fedu', 'traveltime', 'studytime','failures', 'famrel', 'freetime', 'goout', 'Dalc', 'Walc', 'health', 'absences', 'G1', 'G2', 'G3', 'Total_grades']

df0[numeric].hist(figsize=(20,17))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f91684fb150>,
# ...
#       dtype=object)

# %%
df.isnull().values.any()
# Out:
# False

# %%
X = df.iloc[:, :-4].values #All columns until G3
y = df.iloc[:, -1].values

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
ct = ColumnTransformer(transformers = [('encoder', OneHotEncoder(), [0, 1, 3, 4, 5, 8, 9, 10, 11, 15, 16, 17, 18, 19, 20, 21, 22])], remainder="passthrough")
X = np.array(ct.fit_transform(X))

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.24,shuffle = True )

# %%
print(X_train)
# Out:
# [[0.0 1.0 0.0 ... 4 5 2]
#  [0.0 1.0 0.0 ... 3 4 1]
#  [1.0 0.0 1.0 ... 5 4 1]
#  ...
#  [0.0 1.0 0.0 ... 1 1 2]
#  [1.0 0.0 1.0 ... 2 2 1]
#  [0.0 1.0 0.0 ... 4 4 1]]

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
prediction = regressor.predict(X_test)
plt.scatter(y_test,prediction)

# %% [markdown]
# RMSE is the Root of the Mean of the Square of Errors and MAE is the Mean of Absolute value of Errors. Here, errors are the differences between the predicted values (values predicted by regression model) and the actual values of a variable

# %%
from sklearn import metrics

print('MAE:', metrics.mean_absolute_error(y_test, prediction))
print('MSE:', metrics.mean_squared_error(y_test, prediction))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, prediction)))
print('r2_score:', metrics.r2_score(y_test, prediction))
# Out:
# MAE: 1.932895758213141
# MSE: 5.890793282252091
# RMSE: 2.4270956475285623
# r2_score: 0.3329563861374355

# %% [markdown]
# ## **Decision-Tree Based Classification to predict pass/fail**

# %%
df.columns.tolist()
# Out:
# ['school',
#  'sex',
#  'age',
#  'address',
#  'famsize',
#  'Pstatus',
#  'Medu',
#  'Fedu',
#  'Mjob',
#  'Fjob',
#  'reason',
#  'guardian',
#  'traveltime',
#  'studytime',
#  'failures',
#  'schoolsup',
#  'famsup',
#  'paid',
#  'activities',
#  'nursery',
#  'higher',
#  'internet',
#  'romantic',
#  'famrel',
#  'freetime',
#  'goout',
#  'Dalc',
#  'Walc',
#  'health',
#  'absences',
#  'Total_grades']

# %%
grades_pass_fail = []
for index, row in df.iterrows():
    if row['Total_grades'] >= 10:
        grades_pass_fail.append(1) #pass
    else:
        grades_pass_fail.append(0) #fail
        
grades_pass_fail_series = pd.Series(grades_pass_fail)
df["Pass/Fail"] = grades_pass_fail_series

# %%
y = df.iloc[:, -1].values
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, shuffle = True)

# %%
from sklearn.tree import DecisionTreeClassifier
classifier = DecisionTreeClassifier(criterion = 'entropy')
classifier.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy')

# %%
from sklearn.metrics import accuracy_score,classification_report
y_pred = classifier.predict(X_test)
print("Accuracy: {:.2f} %".format(accuracy_score(y_test, y_pred)*100))
# Out:
# Accuracy: 75.38 %

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.53      0.53      0.53        34
#            1       0.83      0.83      0.83        96
#
#     accuracy                           0.75       130
#    macro avg       0.68      0.68      0.68       130
# weighted avg       0.75      0.75      0.75       130

# %%
from sklearn.tree import export_graphviz
from six import StringIO
from IPython.display import Image  
import pydotplus

dot_data = StringIO()
export_graphviz(classifier, out_file=dot_data, filled=True, rounded=True, special_characters=True)
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())  
graph.write_png('diabetes.png')
Image(graph.create_png())

# %% [markdown]
# **Random-Forest Classification to predict pass/fail**

# %%
from sklearn.ensemble import RandomForestClassifier
classifier_rf = RandomForestClassifier(n_estimators = 10, criterion = 'entropy')
classifier_rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(criterion='entropy', n_estimators=10)

# %%
y_pred = classifier_rf.predict(X_test)
print("Accuracy: {:.2f} %".format(accuracy_score(y_test, y_pred)*100))
# Out:
# Accuracy: 78.46 %

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.64      0.41      0.50        34
#            1       0.81      0.92      0.86        96
#
#     accuracy                           0.78       130
#    macro avg       0.73      0.66      0.68       130
# weighted avg       0.77      0.78      0.77       130

# %% [markdown]
# **XGboost to predict pass/fail**

# %%
from xgboost import XGBClassifier
classifier_xgb = XGBClassifier(eval_metric='mlogloss', use_label_encoder=False)
classifier_xgb.fit(X_train, y_train)
# Out:
# XGBClassifier(eval_metric='mlogloss', use_label_encoder=False)

# %%
from sklearn.metrics import confusion_matrix
y_pred = classifier.predict(X_test)
cm = confusion_matrix(y_test, y_pred)
print(cm)
print("Accuracy: {:.2f} %".format(accuracy_score(y_test, y_pred)*100))
# Out:
# [[18 16]
#  [16 80]]
# Accuracy: 75.38 %

# %% [markdown]
# # **Another Model + Cross Validation**

# %%
df1 = pd.read_csv("/content/student-por.csv")

# %%
features_chosen = ['studytime', 'failures', 'Dalc', 'Walc', 'traveltime', 'freetime',  'Medu', 'Fedu', 
                   'sex', 'school', 'address', 'Mjob', 'Fjob', 'reason', 'guardian', 'schoolsup', 
                   'higher', 'internet', 'G1', 'G2', 'G3']

student_reduced = df1[features_chosen].copy()

student_reduced
# Out:
#      studytime  failures  Dalc  Walc  traveltime  ...  higher  internet  G1  G2  G3
# 0            2         0     1     1           2  ...     yes        no   0  11  11
# 1            2         0     1     1           1  ...     yes       yes   9  11  11
# 2            2         0     2     3           1  ...     yes       yes  12  13  12
# 3            3         0     1     1           1  ...     yes       yes  14  14  14
# 4            2         0     1     2           1  ...     yes        no  11  13  13
# ..         ...       ...   ...   ...         ...  ...     ...       ...  ..  ..  ..
# 644          3         1     1     2           1  ...     yes       yes  10  11  10
# 645          2         0     1     1           1  ...     yes       yes  15  15  16
# 646          2         0     1     1           2  ...     yes        no  11  12   9
# 647          1         0     3     4           2  ...     yes       yes  10  10  10
# ...

# %%
# mean
student_reduced["G"]=(student_reduced["G1"]+student_reduced["G2"]+student_reduced["G3"])/3

# dropping initial grades and leaving mean 
student_reduced.drop(['G'], axis=1, inplace=True)

# %%
student_reduced.hist(bins=20, figsize=(20,15))
plt.show()

# %% [markdown]
# get_dummies() method from pandas yields every values from every categorical feature as a column name and assigns 1 to instances where this value is True and  0 to instances where it is not. This method affects only categorical features

# %%
# convert categories from text to numbers.

features_cat = ['sex','school','address','Mjob','Fjob','reason','schoolsup','guardian','higher','internet']

student_reduced_cat = pd.get_dummies(student_reduced, columns = features_cat)
student_reduced_cat
# Out:
#      studytime  failures  Dalc  ...  higher_yes  internet_no  internet_yes
# 0            2         0     1  ...           1            1             0
# 1            2         0     1  ...           1            0             1
# 2            2         0     2  ...           1            0             1
# 3            3         0     1  ...           1            0             1
# 4            2         0     1  ...           1            1             0
# ..         ...       ...   ...  ...         ...          ...           ...
# 644          3         1     1  ...           1            0             1
# 645          2         0     1  ...           1            0             1
# 646          2         0     1  ...           1            1             0
# 647          1         0     3  ...           1            0             1
# 648          1         0     3  ...           1            0             1
#
# [649 rows x 40 columns]

# %%
student_reduced_cat.columns
# Out:
# Index(['studytime', 'failures', 'Dalc', 'Walc', 'traveltime', 'freetime',
#        'Medu', 'Fedu', 'G1', 'G2', 'G3', 'sex_F', 'sex_M', 'school_GP',
#        'school_MS', 'address_R', 'address_U', 'Mjob_at_home', 'Mjob_health',
#        'Mjob_other', 'Mjob_services', 'Mjob_teacher', 'Fjob_at_home',
#        'Fjob_health', 'Fjob_other', 'Fjob_services', 'Fjob_teacher',
#        'reason_course', 'reason_home', 'reason_other', 'reason_reputation',
#        'schoolsup_no', 'schoolsup_yes', 'guardian_father', 'guardian_mother',
#        'guardian_other', 'higher_no', 'higher_yes', 'internet_no',
#        'internet_yes'],
#       dtype='object')

# %%
# Predict and Target variables
 
X = np.array(student_reduced_cat.drop(['G3'],1))
y = np.array(student_reduced_cat['G3'])

# %%
# Scaling numerical variables
scaler = StandardScaler()

X = scaler.fit_transform(X)

# %%
X.shape
# Out:
# (649, 39)

# %%
# Split Data
X_train, X_test,y_train, y_test = train_test_split(X, y, test_size=0.24, random_state=42)

# %%
X_train.shape, X_test.shape
# Out:
# ((493, 39), (156, 39))

# %% [markdown]
#  **Linear Regression with regularization**

# %%
from sklearn.linear_model import SGDRegressor

sgd_reg = SGDRegressor(penalty="l2") # specifying Ridge Regression

sgd_reg.fit(X_train, y_train)
# Out:
# SGDRegressor()

# %%
accuracy=sgd_reg.score(X_test,y_test)  
accuracy
# Out:
# 0.8629611686818576

# %%
X_train.shape, X_test.shape
# Out:
# ((493, 39), (156, 39))

# %% [markdown]
# Maybe we nwwd to be sure that our model is not underfit or overfit by using Learning curve and Cross-validation

# %% [markdown]
# ## **Learning curves**

# %%
def plot_learning_curves(model, X, y):
    X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.2) 
    train_errors, val_errors = [], []
    
    for m in range(1, len(X_train)):
        model.fit(X_train[:m], y_train[:m])
        y_train_predict = model.predict(X_train[:m])
        y_val_predict = model.predict(X_val) 
        train_errors.append(mean_squared_error(y_train[:m], y_train_predict)) 
        val_errors.append(mean_squared_error(y_val, y_val_predict))
        
    plt.plot(np.sqrt(train_errors), "r-+", linewidth=2, label="train") 
    plt.plot(np.sqrt(val_errors), "b-", linewidth=3, label="val")

# %%
from sklearn.metrics import mean_squared_error
sgd_reg_curves = SGDRegressor(penalty='l2') 

plot_learning_curves(sgd_reg_curves, X, y)

# %% [markdown]
# The curve shows that the model is fine

# %% [markdown]
# ## **Cross-Validation**

# %%
from sklearn.model_selection import cross_val_score
scores = cross_val_score(sgd_reg, X_train, y_train, scoring="neg_mean_squared_error", cv=10) 

sgd_reg_scores = np.sqrt(-scores)

# %%
sgd_reg_scores
# Out:
# array([1.18049453, 1.65160585, 1.8897089 , 1.53776502, 1.59462625,
#        1.1259129 , 1.25616449, 0.94426302, 1.07433674, 0.80430419])

# %%
def display_scores(scores):
    print('Scores:', scores)
    print('Std.  :', scores.std())
    print('Mean  :', scores.mean())
    
display_scores(sgd_reg_scores)
# Out:
# Scores: [1.18049453 1.65160585 1.8897089  1.53776502 1.59462625 1.1259129
#  1.25616449 0.94426302 1.07433674 0.80430419]
# Std.  : 0.3292516223564457
# Mean  : 1.3059181897254444

# %% [markdown]
# We can conclude that the cross Validation and the curve are correct, identifies that our model LinearRegression with regularisation works fine and that there is no underfitting or overfitting
